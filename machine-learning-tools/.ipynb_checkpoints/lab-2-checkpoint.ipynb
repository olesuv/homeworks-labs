# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# /tmp/ipykernel_390811/1505719282.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('./assets/employees.csv')

# %%
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# 2               False               Finance
# 3                True               Finance
# 4                True       Client Services
# ..                ...                   ...
# 995             False          Distribution
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales
#
# [1000 rows x 8 columns]

# %%
check_nan = df.isnull().any()
check_nan
# Out:
# First Name            True
# Gender                True
# Start Date           False
# Last Login Time      False
# Salary               False
# Bonus %              False
# Senior Management     True
# Team                  True
# dtype: bool

# %%
delete_nan = df.dropna()
delete_nan
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male  4/18/1987         1:35 AM  115163   10.125
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 2               False               Finance
# 3                True               Finance
# 4                True       Client Services
# 5               False                 Legal
# ..                ...                   ...
# 994              True             Marketing
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales
#
# [764 rows x 8 columns]

# %%
delete_nan.isnull().values.any()
# Out:
# False

# %%
team_counts = delete_nan.groupby(['Team']).count()
team_counts
# Out:
#                       First Name  Gender  Start Date  Last Login Time  Salary  \
# Team
# Business Development          88      88          88               88      88
# Client Services               85      85          85               85      85
# Distribution                  60      60          60               60      60
# Engineering                   79      79          79               79      79
# Finance                       80      80          80               80      80
# Human Resources               76      76          76               76      76
# Legal                         67      67          67               67      67
# Marketing                     74      74          74               74      74
# Product                       83      83          83               83      83
# Sales                         72      72          72               72      72
#
#                       Bonus %  Senior Management
# Team
# Business Development       88                 88
# Client Services            85                 85
# Distribution               60                 60
# Engineering                79                 79
# Finance                    80                 80
# Human Resources            76                 76
# Legal                      67                 67
# Marketing                  74                 74
# Product                    83                 83
# Sales                      72                 72

# %%
team_info = delete_nan.groupby('Team')['Salary'].agg(['min', 'mean', 'max']).sort_values(by='mean')
team_info
# Out:
#                         min          mean     max
# Team
# Distribution          35575  85849.100000  149105
# Product               35013  86935.963855  149684
# Legal                 35061  88066.402985  148985
# Client Services       35095  89336.658824  147183
# Business Development  36844  90520.397727  147417
# Marketing             36643  90764.081081  146812
# Human Resources       35203  91145.171053  149903
# Sales                 35802  91724.819444  144887
# Engineering           36946  94369.405063  147362
# Finance               35381  94519.075000  149908

# %%
team_info.plot(kind='bar', figsize=(10, 2))
plt.title('Заробітна плата в залежності від команди')
plt.xlabel('Команда')
plt.ylabel('Заробітна плата')
plt.show()

# %%
gender_bonus_avg = delete_nan.groupby('Gender')['Bonus %'].median()
gender_bonus_avg
# Out:
# Gender
# Female     9.375
# Male      10.169
# Name: Bonus %, dtype: float64

# %%
gender_bonus_avg.plot(kind='pie', autopct='%1.1f%%', colors=['pink', 'blue'], figsize=(10, 4), legend=False)
plt.title('Розподіл бонусів в залежності від статі')
plt.ylabel('')
plt.show()

# %%
df = pd.read_csv('./assets/nba.csv')
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University        NaN
# 3        Georgia State  1148640.0
# 4                  NaN  5000000.0
# ..                 ...        ...
# 453             Butler  2433333.0
# 454                NaN   900000.0
# 455                NaN  2900000.0
# 456             Kansas   947276.0
# 457                NaN        NaN
#
# [458 rows x 9 columns]

# %%
df.isnull().any()
# Out:
# Name        True
# Team        True
# Number      True
# Position    True
# Age         True
# Height      True
# Weight      True
# College     True
# Salary      True
# dtype: bool

# %%
df = df.dropna()

# %%
df.isnull().any()
# Out:
# Name        False
# Team        False
# Number      False
# Position    False
# Age         False
# Height      False
# Weight      False
# College     False
# Salary      False
# dtype: bool

# %%
df['Weight'] *= 0.45359237
df
# Out:
# /tmp/ipykernel_390811/3344734492.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Weight'] *= 0.45359237
#               Name            Team  Number Position   Age Height      Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   81.646627
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6  106.594207
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   83.914588
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8  106.594207
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0  107.954984
# ..             ...             ...     ...      ...   ...    ...         ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   93.440028
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   93.440028
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10  106.140615
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   92.079251
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0  104.779837
#
#            College     Salary
# 0            Texas  7730337.0
# 1        Marquette  6796117.0
# 3    Georgia State  1148640.0
# 6              LSU  1170960.0
# 7          Gonzaga  2165160.0
# ..             ...        ...
# 449           Duke  1348440.0
# 451         Dayton   981348.0
# 452       Kentucky  2239800.0
# 453         Butler  2433333.0
# 456         Kansas   947276.0
#
# [364 rows x 9 columns]

# %%
df['Height'] = df['Height'].astype(str)

def convert_to_cm(df):
    for height in df['Height']:
        feet, inches = map(int, height.split('-'))
        cm = feet * 30.48 + inches * 2.54
        print(cm)
        df['Height'] = cm

    return df

# %%
df = convert_to_cm(df)
df

# %%
team_count_df = df.groupby('Team').size().reset_index(name='Count')
team_count_df
# Out:
#                       Team  Count
# 0            Atlanta Hawks     11
# 1           Boston Celtics     12
# 2            Brooklyn Nets     13
# 3        Charlotte Hornets     13
# 4            Chicago Bulls     12
# 5      Cleveland Cavaliers     11
# 6         Dallas Mavericks     12
# 7           Denver Nuggets      9
# 8          Detroit Pistons     15
# 9    Golden State Warriors     12
# 10         Houston Rockets     11
# 11          Indiana Pacers     12
# 12    Los Angeles Clippers     14
# 13      Los Angeles Lakers     12
# 14       Memphis Grizzlies     13
# 15              Miami Heat     10
# 16         Milwaukee Bucks     14
# 17  Minnesota Timberwolves      8
# 18    New Orleans Pelicans     16
# 19         New York Knicks     11
# 20   Oklahoma City Thunder     14
# 21           Orlando Magic     10
# 22      Philadelphia 76ers     14
# 23            Phoenix Suns     13
# 24  Portland Trail Blazers     15
# 25        Sacramento Kings     13
# 26       San Antonio Spurs     11
# 27         Toronto Raptors     10
# 28               Utah Jazz     10
# 29      Washington Wizards     13

# %%
team_info = df.groupby('Team')['Salary'].agg(['min', 'mean', 'max']).reset_index()
team_info = result_df.sort_values(by='mean')
team_info
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 team_info = df.groupby('Team')['Salary'].agg(['min', 'mean', 'max']).reset_index()
# ----> 2 team_info = result_df.sort_values(by='mean')
#       3 team_info
#
# NameError: name 'result_df' is not defined

# %%
team_info.plot(x='Team', kind='bar', figsize=(10, 3))
plt.title('Заробітна плата за командами')
plt.xlabel('Команда')
plt.ylabel('Заробітна плата')
plt.legend(['Мінімум', 'Середнє', 'Максимум'])
plt.show()

# %%
plt.figure(figsize=(10, 3))
plt.scatter(df['Weight'], df['Height'], color='red', alpha=0.3)
plt.title('Графік розкиду ваги та висоти гравців')
plt.xlabel('Вага')
plt.ylabel('Висота')
plt.grid(True)
plt.show()

# %%
position_age_df = df.groupby('Position')['Age'].mean().reset_index()
position_age_df

# %%
plt.figure(figsize=(10, 6))
plt.bar(position_age_df['Position'], position_age_df['Age'], color='blue')
plt.title('Середній вік гравців за позицією')
plt.xlabel('Позиція')
plt.ylabel('Середній вік')
plt.grid(True)
plt.show()
