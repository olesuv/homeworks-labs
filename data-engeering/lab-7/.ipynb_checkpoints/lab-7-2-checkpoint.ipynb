# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("hr_data.csv")
df
# Out:
#                   Name  Age  Gender  Projects Completed  Productivity (%)  \
# 0      Douglas Lindsey   25    Male                  11                57
# 1     Anthony Roberson   59  Female                  19                55
# 2        Thomas Miller   30    Male                   8                87
# 3         Joshua Lewis   26  Female                   1                53
# 4     Stephanie Bailey   43    Male                  14                 3
# ..                 ...  ...     ...                 ...               ...
# 195   Stephanie Fisher   29  Female                   9                32
# 196      Jeremy Miller   26    Male                   7                45
# 197      Daniel Pierce   22    Male                   3                36
# 198  Michael Hernandez   36  Female                  23                96
# 199   Victor Gutierrez   43    Male                  10                86
#
#      Satisfaction Rate (%)  Feedback Score Department          Position  \
# ...

# %% [markdown]
# ### Кластеризація по `Age` та `Productivity` використовуючи алгоритм `K-means`

# %%
df_age_productivity = df.iloc[:, [1, 4]]
df_age_productivity
# Out:
#      Age  Productivity (%)
# 0     25                57
# 1     59                55
# 2     30                87
# 3     26                53
# 4     43                 3
# ..   ...               ...
# 195   29                32
# 196   26                45
# 197   22                36
# 198   36                96
# 199   43                86
#
# [200 rows x 2 columns]

# %%
kmeans = KMeans(n_clusters=5, random_state=0, n_init='auto').fit(df_age_productivity)

df['cluster'] = kmeans.fit_predict(df_age_productivity)

# kmeans.cluster_centers_
# # kmeans.predict([[0, 0], [20, 95]])

# %%
plt.scatter(df['Age'], df['Productivity (%)'], c=df['cluster'], cmap='viridis', edgecolors='k', s=50)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='.', label='Center of cluster')

plt.xlabel('Age')
plt.ylabel('Productivity')
plt.title('K-means Clustering of Age and Productivity')

plt.legend()
plt.show()

# %% [markdown]
# ### Кластеризація по `Productivity` та `Satisfaction Rate` використовуючи алгоритм `K-means`

# %%
df_productivity_satisfaction = df.iloc[:, [4, 5]]

df_productivity_satisfaction
# Out:
#      Productivity (%)  Satisfaction Rate (%)
# 0                  57                     25
# 1                  55                     76
# 2                  87                     10
# 3                  53                      4
# 4                   3                      9
# ..                ...                    ...
# 195                32                     87
# 196                45                     28
# 197                36                     77
# 198                96                     50
# 199                86                     71
#
# [200 rows x 2 columns]

# %%
kmeans = KMeans(n_clusters=4, random_state=0, n_init='auto').fit(df_productivity_satisfaction)

df['cluster-1'] = kmeans.fit_predict(df_productivity_satisfaction)

kmeans.cluster_centers_
# Out:
# array([[30.79365079, 73.84126984],
#        [20.82692308, 26.90384615],
#        [67.73170732, 19.3902439 ],
#        [80.70454545, 71.38636364]])

# %%
plt.scatter(df['Productivity (%)'], df['Satisfaction Rate (%)'], c=df['cluster-1'], cmap='viridis', edgecolors='k', s=50)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='.', label='Center of cluster')

plt.xlabel('Productivity')
plt.ylabel('Satisfaction Rate')
plt.title('K-means Clustering of Productivity and Satisfaction Rate')

plt.legend()
plt.show()
